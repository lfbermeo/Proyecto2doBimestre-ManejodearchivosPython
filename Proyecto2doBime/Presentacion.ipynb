# %% [markdown]
# # Trabajo final

# %% [markdown]
# ### Programación de algoritmos

# %% [markdown]
# ### OBJETIVO GENERAL:
# Procesar datos extensos (csv's), filtrando unicamente la informacion deseada para la posterior representación gráfica estadística de los datos  haciendo uso de la libreria **Bokeh**.
# ### Jupyter
# Trabajamos con Jupyter mediante su notebook ya instalado en nuestro PC. Utilizamos el lenguaje **Python** con su version más reciente.
# ### Pandas
# Importamos la libreria `pandas` para leer la base de datos en formato .csv y la denominamos `pd`.

# %% [markdown]
# ### Nacimientos 2014

# %% [markdown]
# Con las Estadísticas Vitales (Nacimientos )se ofrece información . Se da a conocer a los usuarios, las variables más relevantes en este campo, que sirve para la planificación de estrategias socio-económicas del país y proporcionan a los sectores público y privado, uno de los instrumentos básicos para el análisis demográfico.[Más información](http://ambar.utpl.edu.ec/dataset/nacimientos-2014)

# %%
import pandas as pd

# %%
datos_nacimientos = pd.read_csv('data/nacimientos2014.csv', engine='python')
datos_nacimientos
# Out:
#       Unnamed: 0                tip_insc  ofi_insc  \
# 0              1    Inscripciï¿½n Normal         1
# 1              2    Inscripciï¿½n Normal         1
# 2              3    Inscripciï¿½n Normal         1
# 3              4    Inscripciï¿½n Normal         1
# 4              5    Inscripciï¿½n Normal         1
# 5              6    Inscripciï¿½n Normal         1
# 6              7  Inscripciï¿½n Tardï¿½a         1
# 7              8    Inscripciï¿½n Normal         1
# 8              9  Inscripciï¿½n Tardï¿½a         1
# 9             10    Inscripciï¿½n Normal         1
# 10            11  Inscripciï¿½n Tardï¿½a         1
# 11            12    Inscripciï¿½n Normal         1
# 12            13    Inscripciï¿½n Normal         1
# 13            14    Inscripciï¿½n Normal         1
# 14            15    Inscripciï¿½n Normal         1
# 15            16    Inscripciï¿½n Normal         1
# 16            17    Inscripciï¿½n Normal         1
# ...

# %%
datos_nacimientos.columns
# Out:
# Index(['Unnamed: 0', 'tip_insc', 'ofi_insc', 'prov_insc', 'cant_insc',
#        'parr_insc', 'anio_insc', 'mes_insc', 'dia_insc', 'fecha_insc', 'sexo',
#        'talla', 'peso', 'sem_gest', 'tipo_part', 'anio_nac', 'mes_nac',
#        'dia_nac', 'fecha_nac', 'p_emb', 'lugar_ocur', 'prov_nac', 'cant_nac',
#        'parr_nac', 'area_nac', 'asis_por', 'nac_mad', 'cod_pais', 'anio_mad',
#        'mes_mad', 'dia_mad', 'fecha_mad', 'edad_mad', 'con_pren', 'num_par',
#        'hij_viv', 'hij_vivm', 'hij_nacm', 'etnia', 'est_civil', 'sabe_leer',
#        'niv_inst', 'prov_res', 'cant_res', 'parr_res', 'area_res'],
#       dtype='object')

# %% [markdown]
# ### Bibliografia:
# Para realizar los graficos utilizamos la libreria bokeh.
# [Bokeh](https://bokeh.pydata.org/en/latest/)
#
# Usamos Jupyter como plataforma web para crear y visualizar las gráficas
# [Jupyter](http://jupyter.org/)
#
# Para leer el archivo csv y poder trabajar con los datos en el use Pandas, otra libreria de Python.
# [Pandas](http://pandas.pydata.org/)
#
# Tome de referencia la documentación que tiene l librería bokeh para algunas funcones implementadas en las gráficas
# [Documentación bokeh](https://bokeh.pydata.org/en/latest/docs/user_guide/notebook.html)
